# %% [markdown]
# <a href="https://colab.research.google.com/github/CSID-DGU/2021-1-OSSP1-Debugger-4/blob/autoencoder/up_scailing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd ./drive/MyDrive/up_scailing/
# Out:
# /content/drive/MyDrive/up_scailing

# %%
pwd
# Out:
# '/content/drive/My Drive/up_scailing'

# %%
# !git clone https://github.com/idealo/image-super-resolution
# Out:
# Cloning into 'image-super-resolution'...
# remote: Enumerating objects: 1193, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 1193 (delta 0), reused 0 (delta 0), pack-reused 1187
# Receiving objects: 100% (1193/1193), 14.95 MiB | 15.68 MiB/s, done.
# Resolving deltas: 100% (594/594), done.

# %%
cd ./image-super-resolution/
# Out:
# /content/drive/My Drive/up_scailing/image-super-resolution

# %%
import numpy as np
from PIL import Image

img = Image.open('./images/A_0.jpg')
lr_img = np.array(img)

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.show()

# %%
from ISR.models import RDN

rdn = RDN(weights='psnr-small')
sr_img = rdn.predict(lr_img)
# Out:
# ...
# 10698752/10694096 [==============================] - 1s 0us/step

# %%
plt.imshow(sr_img)
plt.show()
