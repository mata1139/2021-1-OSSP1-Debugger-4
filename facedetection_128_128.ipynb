# %% [markdown]
# <a href="https://colab.research.google.com/github/CSID-DGU/2021-1-OSSP1-Debugger-4/blob/face-recognization/facedetection_128_128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from imutils import face_utils
from google.colab.patches import cv2_imshow
import numpy as np
import imutils
import dlib
import cv2
import os
import math

detector = dlib.get_frontal_face_detector()

image = cv2.imread('/gdrive/MyDrive/face1.jpg')

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
rects = detector(gray, 1)
for i in rects:
  x1 = i.left()
  x2 = i.right()
  y1 = i.top()
  y2 = i.bottom()


img = image[y1:y2, x1:x2]
img = cv2.resize(img, dsize=(128, 128), interpolation=cv2.INTER_AREA)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F1DFDFBFF90>
