# %% [markdown]
# <a href="https://colab.research.google.com/github/CSID-DGU/2021-1-OSSP1-Debugger-4/blob/face-recognization/FaceRotate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import cv2
from google.colab.patches import cv2_imshow

# cos값을 통한 회전
#print(landmark1[36][0], landmark1[36][1], landmark1[45][0], landmark1[45][1], landmark2[36][0], landmark2[36][1], landmark2[45][0], landmark2[45][1])
#tan1 = np.arctan2(9,385)
#angle = np.rad2deg(tan1)
#print(angle)

#이에 따라 바뀐 size배수
#s = np.cos(tan1)*s

src = cv2.imread('/gdrive/MyDrive/res2.jpg')

if src is None:
    print('Image load failed!')
    sys.exit()

cp = (src.shape[1] / 2, src.shape[0] / 2)
rot = cv2.getRotationMatrix2D(cp, -1.3391379629296052, 1)

dst = cv2.warpAffine(src, rot, (0, 0))

cv2.imwrite('/gdrive/MyDrive/res2.jpg',dst)

#cv2_imshow(src)
cv2_imshow(dst)
cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=501x439 at 0x7F37EA738610>
