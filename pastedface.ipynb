# %% [markdown]
# <a href="https://colab.research.google.com/github/CSID-DGU/2021-1-OSSP1-Debugger-4/blob/face-recognization/pastedface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from imutils import face_utils
from google.colab.patches import cv2_imshow
import numpy as np
import imutils
import dlib
import cv2
import math

img = cv2.imread('/gdrive/MyDrive/마스크 와꾸.jpg')
def func(hpos, vpos, size):
  src = cv2.imread('/gdrive/MyDrive/result.png')
  src = cv2.resize(src, dsize=(0,0), fx =size, fy= size, interpolation = cv2.INTER_LINEAR)
  rows, cols, channels = src.shape
  roi = img[vpos:rows+vpos, hpos:cols+hpos]

  img2gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
  ret, mask = cv2.threshold(img2gray, 10, 255, cv2.THRESH_BINARY)
  mask_inv = cv2.bitwise_not(mask)

  img_bg = cv2.bitwise_and(roi, roi, mask=mask_inv)
  src_fg = cv2.bitwise_and(src, src, mask=mask)

  tmp = cv2.add(img_bg, src_fg)
  img[vpos:rows+vpos, hpos:cols+hpos] = tmp

  cv2_imshow(tmp)
  cv2_imshow(img) 

func(260,520, 3.65)
# Out:
# <PIL.Image.Image image mode=RGB size=620x442 at 0x7FAB515822D0>
# <PIL.Image.Image image mode=RGB size=1080x1440 at 0x7FAB51597AD0>
