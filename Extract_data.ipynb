# %% [markdown]
# <a href="https://colab.research.google.com/github/CSID-DGU/2021-1-OSSP1-Debugger-4/blob/autoencoder/Extract_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 0-43199까지의 파일 중
#
# S003
#
# L5-L6
#
# C15-C17 C19-C20
#
# 을 빼고
#
# S001,S002
#
# L1-L4
#
# E1-E2
#
# C4-C10
#
# 만 뽑아낼 수 있게 해보자

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 100명별로 indexing된 자료들 중 필요한 부분의 숫자를 뽑아내는 부분

# %%
import sys, os

num = 0
index = []
for a in range(100):
  for i in range(2): #S001-S002
    #print('S' + str(i + 1))
    for j in range(4): #L1-L4
      #print('L' + str(j + 1))
      for k in range(2): #E1-E2
        #print('E' + str(k + 1))
        for x in range(7): #C달고있는 12개 중 7개만
          index.append(num)
        num = num + 5
    num = num + 48

# %%
print(len(index))
# Out:
# 11200

# %% [markdown]
# 모든 사람에 대하여 파일 경로를 추출하여 filepath에 저장

# %%
rootpath = ['./drive/MyDrive/A_Complete', './drive/MyDrive/B_complete', './drive/MyDrive/C_Complete', './drive/MyDrive/D_Complete']
filename = ['/A_', '/B_', '/A_', '/D_']

filepath = []

for i in range(4):
  temp = rootpath[i] + filename[i]
  for j in range(len(index)):
    path = temp + str(index[j])
    filepath.append(path)
  #path[i].append

# %%
len(filepath)
# Out:
# 44800

# %%
print(filepath)
# Out:
# ['./drive/MyDrive/A_Complete/A_0', './drive/MyDrive/A_Complete/A_0', './drive/MyDrive/A_Complete/A_0', './drive/MyDrive/A_Complete/A_0', './drive/MyDrive/A_Complete/A_0', './drive/MyDrive/A_Complete/A_0', './drive/MyDrive/A_Complete/A_0', './drive/MyDrive/A_Complete/A_5', './drive/MyDrive/A_Complete/A_5', './drive/MyDrive/A_Complete/A_5', './drive/MyDrive/A_Complete/A_5', './drive/MyDrive/A_Complete/A_5', './drive/MyDrive/A_Complete/A_5', './drive/MyDrive/A_Complete/A_5', './drive/MyDrive/A_Complete/A_10', './drive/MyDrive/A_Complete/A_10', './drive/MyDrive/A_Complete/A_10', './drive/MyDrive/A_Complete/A_10', './drive/MyDrive/A_Complete/A_10', './drive/MyDrive/A_Complete/A_10', './drive/MyDrive/A_Complete/A_10', './drive/MyDrive/A_Complete/A_15', './drive/MyDrive/A_Complete/A_15', './drive/MyDrive/A_Complete/A_15', './drive/MyDrive/A_Complete/A_15', './drive/MyDrive/A_Complete/A_15', './drive/MyDrive/A_Complete/A_15', './drive/MyDrive/A_Complete/A_15', './drive/MyDrive/A_Complete/A_20', './drive/MyDrive/A_Complete/A_20', './drive/MyDrive/A_Complete/A_20', './drive/MyDrive/A_Complete/A_20', './drive/MyDrive/A_Complete/A_20', './drive/MyDrive/A_Complete/A_20', './drive/MyDrive/A_Complete/A_20', './drive/MyDrive/A_Complete/A_25', './drive/MyDrive/A_Complete/A_25', './drive/MyDrive/A_Complete/A_25', './drive/MyDrive/A_Complete/A_25', './drive/MyDrive/A_Complete/A_25', './drive/My