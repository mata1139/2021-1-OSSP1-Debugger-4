# %% [markdown]
# <a href="https://colab.research.google.com/github/CSID-DGU/2021-1-OSSP1-Debugger-4/blob/autoencoder/canfindFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import cv2
import dlib
import imutils
import numpy as np
from google.colab.patches import cv2_imshow
from imutils import face_utils

detector = dlib.get_frontal_face_detector()
img = cv2.imread('/gdrive/MyDrive/opencv/C19.jpg')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#cv2_imshow(gray)
rects = detector(gray,1)
roi = rects[0]
(x,y,w,h) = face_utils.rect_to_bb(roi)
cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),3)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=864x576 at 0x7F635C0F8050>
